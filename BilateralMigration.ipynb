# %% [markdown]
# ## From country to country

# %%
df_migr_tot.head(10)
# Out:
#           Origin          Destination  Year  value
# 462  Afghanistan          Afghanistan  1960    0.0
# 463  Afghanistan              Albania  1960    0.0
# 464  Afghanistan              Algeria  1960   41.0
# 465  Afghanistan       American Samoa  1960    0.0
# 466  Afghanistan              Andorra  1960    0.0
# 467  Afghanistan               Angola  1960    0.0
# 468  Afghanistan             Anguilla  1960    0.0
# 469  Afghanistan  Antigua and Barbuda  1960    0.0
# 470  Afghanistan            Argentina  1960    6.0
# 471  Afghanistan              Armenia  1960    0.0

# %%
average_flux = df_migr_tot.pivot_table(values='value',index='Origin',columns='Destination')
average_flux.head()
# Out:
# Destination     Afghanistan  Albania  Algeria  American Samoa  Andorra  \
# Origin
# Afghanistan             0.0      0.0     17.6             0.0      2.6
# Albania                 0.6      0.0      6.8             0.0     66.4
# Algeria                28.2      0.0      0.0             0.0    110.0
# American Samoa          0.2      0.0      0.0             0.0      0.0
# Andorra                 0.0      0.0      0.2             0.0      0.0
#
# Destination     Angola  Anguilla  Antigua and Barbuda  Argentina  Armenia  \
# Origin
# Afghanistan        0.0       0.0                  0.0        9.8      1.4
# Albania            1.6       0.0                  0.0       43.8      1.4
# Algeria            4.2       0.0                  4.4       67.2      0.0
# American Samoa     0.0       0.0                  1.8        0.0      0.0
# Andorra            0.2       0.0                  0.0        2.4      0.0
#
# Destination       ...     Vanuatu  Venezuela, RB  Vietnam  \
# ...

# %%
df_migr_tot['Country']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2392             try:
# -> 2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20405)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20359)()
#
# KeyError: 'Country'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %% [markdown]
# Include region

# %%
countries = pd.read_csv('data/countries.csv')
countries = countries[['ShortName','Region']]
countries.columns = ['Country','Region']

# %%
# create country-region mapping dataframe
country_region = pd.DataFrame(countries['Region'],index=countries['Country'])
# join it with indicator dataframe
data_set_cut = data_set_cut.join(country_region, on = 'Country')

# %%
data_set_origin = data_set_cut.rename(columns = {'Country':'Origin'})
data_set_destination = data_set_cut.rename(columns = {'Country':'Destination'})

# %%
df_migr_ind = pd.merge(df_migr_tot,data_set_origin,on=['Origin','Year'])
df_migr_ind = pd.merge(df_migr_ind,data_set_destination,on=['Destination','Year'])

# %%
df_migr_ind.shape

# %% [markdown]
# Huge increase in datapoints.

# %%
df_migr_ind.head()
